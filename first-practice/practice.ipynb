# %%
import pandas as pd

extreme_donosti = pd.read_csv("Datos_ValoresExtremos_P.csv")
extreme_donosti
# Out:
#   indicativo                         nombre ubicacion  codigo  \
# 0      1024E  DONOSTIA / SAN SEBASTI�N;IGEL  GIPUZKOA   33100
#
#                            maxDiasMesPrec  \
# 0  25;22;26;28;26;26;24;26;26;26;25;28;28
#
#                                   anioMaxDiasMesPrec  mesMaxDiasMesPrec  \
# 0  1955;2007;2001;2012;1988;1933;2007;1963;1995;1...                 12
#
#                maxDiasMesNieve  \
# 0  9;10;5;4;1;0;0;0;0;1;3;5;10
#
#                                  anioMaxDiasMesNieve  mesMaxDiasMesNieve  ...  \
# 0  1945;2005;1955;1986;1947;2025;2025;2025;2025;1...                   2  ...
#
#                                           precMaxDia  \
# 0  756;843;846;702;1677;973;1156;1310;1671;1351;8...
#
#                                diaMaxDia  \
# 0  16;17;25;13;31;15;3;23;30;25;29;29;31
#
#                                           anioMaxDia mesMaxDia  \
# 0  2023;1940;1968;1942;1997;1933;1952;2007;1949;1...         5
#
# ...

# %%
list(extreme_donosti["maxDiasMesPrec"])[0].split(";")
# Out:
# ['25', '22', '26', '28', '26', '26', '24', '26', '26', '26', '25', '28', '28']

# %%
list(extreme_donosti["anioMaxDiasMesPrec"])[0].split(";")
# Out:
# ['1955',
#  '2007',
#  '2001',
#  '2012',
#  '1988',
#  '1933',
#  '2007',
#  '1963',
#  '1995',
#  '1993',
#  '2023',
#  '1993',
#  '1993']
